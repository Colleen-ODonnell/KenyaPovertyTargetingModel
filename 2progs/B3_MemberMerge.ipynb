# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
import statsmodels.api as sm

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-0e919de7038c> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
MergeTotalCost = pd.read_excel('../2progs/Excel_Files/C2_DescriptiveStats.xlsx')
Member = pd.read_excel('../2progs/Excel_Files/B1_MemberCleaning.xlsx')

# %%
FinalMerge = pd.merge(Member, MergeTotalCost, how = "inner", on = "hhid")

# %%
FinalMerge.describe()
# Out:
#               hhid         size   headFemale  shareFemale  shareAgeZeroToFour  \
# count  1090.000000  1090.000000  1090.000000  1090.000000         1090.000000
# mean   2914.844037     5.764220     0.657798     0.488215            0.190778
# std    1720.548935     3.075781     0.474665     0.256535            0.165900
# min      10.000000     1.000000     0.000000     0.000000            0.000000
# 25%    1435.250000     4.000000     0.000000     0.333333            0.000000
# 50%    2832.500000     6.000000     1.000000     0.500000            0.200000
# 75%    4427.000000     8.000000     1.000000     0.666667            0.326923
# max    6004.000000    21.000000     1.000000     1.000000            0.750000
#
#        shareAgeFiveToNine  shareAgeTenToFourteen  shareAgeFifteenToTwentyfour  \
# count         1090.000000            1090.000000                  1090.000000
# mean             0.190811               0.147147                     0.220717
# ...

# %%
FinalMerge.to_excel('../2progs/Excel_Files/C3_FinalMerge.xlsx',sheet_name='Sheet1')
