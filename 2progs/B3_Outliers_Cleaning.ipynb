# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
MergedDatasetsRenamed = pd.read_excel('../2progs/MergedDatasetsRenamed.xlsx',sheet_name='Sheet1',index_col = 0)

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_tuitionfees > 34673),'spend_tuitionfees'] = np.nan

# %%
MergedDatasetsRenamed['spend_tuitionfees'].describe()
# Out:
# count    18044.000000
# mean       398.346267
# std       2445.767511
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      32000.000980
# Name: spend_tuitionfees, dtype: float64

# %%
MergedDatasetsRenamed.iloc[[5471]]
# Out:
#       hhid     s1q2_x  spend_tuitionfees  spend_textbooks  \
# 5471  1717  Village 3                NaN      3499.999878
#
#       spend_exercisebooks  spend_schooluniform  spend_schoolboardingfees  \
# 5471            49.999998                  1.0                       0.0
#
#       spend_schooltransport  spend_extratuition  spend_PTA  ...     hh_con  \
# 5471            9999.999756                 0.0        0.0  ...  2910.2168
#
#       hh_con2011  hh_con2011_pd  pline_ipl  poorIPL       pgi       spg  \
# 5471   51.498955       1.693116        1.9     Poor  0.167023  0.027897
#
#       weight_y.1  popweight   Dataset2
# 5471    5.557169  55.571686  Household
#
# [1 rows x 144 columns]

# %%
MergedDatasetsRenamed.iloc[[4078]]
# Out:
#       hhid     s1q2_x  spend_tuitionfees  spend_textbooks  \
# 4078  1281  Village 1                NaN           2000.0
#
#       spend_exercisebooks  spend_schooluniform  spend_schoolboardingfees  \
# 4078                  0.0               4200.0                       0.0
#
#       spend_schooltransport  spend_extratuition  spend_PTA  ...     hh_con  \
# 4078                    0.0                 0.0        0.0  ...  3448.3696
#
#       hh_con2011  hh_con2011_pd  pline_ipl   poorIPL       pgi       spg  \
# 4078   61.022064       2.006205        1.9  Non-poor  0.043269  0.001872
#
#       weight_y.1  popweight   Dataset2
# 4078    5.557169  77.800362  Household
#
# [1 rows x 144 columns]

# %%
MergedDatasetsRenamed.head()
# Out:
#    hhid     s1q2_x  spend_tuitionfees  spend_textbooks  spend_exercisebooks  \
# 0    10  Village 1                0.0              0.0               2400.0
# 1    10  Village 1                0.0              0.0               2400.0
# 2    10  Village 1                0.0              0.0               2400.0
# 3    10  Village 1                0.0              0.0               2400.0
# 4    10  Village 1                0.0              0.0               2400.0
#
#    spend_schooluniform  spend_schoolboardingfees  spend_schooltransport  \
# 0                  0.0                    6000.0                 3000.0
# 1                  0.0                    6000.0                 3000.0
# 2                  0.0                    6000.0                 3000.0
# 3                  0.0                    6000.0                 3000.0
# 4                  0.0                    6000.0                 3000.0
#
# ...

# %%
#Change outliers to NAs
MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_textbooks > 5614),'spend_textbooks']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_exercisebooks > 3845),'spend_exercisebooks']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_schooluniform > 7563),'spend_schooluniform']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_schooltransport > 41465),'spend_schooltransport']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_PTA > 1577),'spend_PTA']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_pocketmoney > 17225),'spend_pocketmoney']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_cautionmoney > 4989),'spend_cautionmoney']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_educmedicalfee > 12576),'spend_educmedicalfee']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_activityfees > 2277),'spend_activityfees']= np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_examfees > 4527),'spend_examfees']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_educfeedingprogram > 53368),'spend_educfeedingprogram']=  np.nan

# %%
#Change outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.spend_othereduccharges > 6135),'spend_othereduccharges']=  np.nan

# %%
#Energy Dataset - switching outliers to NAs

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.totalcost_purchasedfirewood > 913),'totalcost_purchasedfirewood']=  np.nan

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.totalcost_collectedfirewood > 1363),'totalcost_collectedfirewood']=  np.nan

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.totalcost_charcoal > 1134),'totalcost_charcoal']=  np.nan

# %%
#430 outliers for Energy dataset
#821 outliers for Education dataset (outlier defined as observations were more than 3 SD away from mean excluding 0's)
#still changing less than 1% of dataset (dataset has 18080 observations)

# %%
#Food Dataset - Change outliers to NAs 

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.amountfood_purchased7d > 1255), 'amountfood_purchased7d']=  np.nan

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.foodspent_localcurrecny > 2065), 'foodspent_localcurrecny']=  np.nan

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.foodconsumed7d > 542), 'foodconsumed7d']=  np.nan

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.foodconsumed7d > 2.9), 'quantityfood_consumedkg_pc']=  np.nan

# %%
#750 outliers for Food dataset

# %%
#Household Dataset - Change outliers to NAs 

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.number_dwellings > 3), 'number_dwellings']=  np.nan

MergedDatasetsRenamed.loc[(MergedDatasetsRenamed.number_habitablerooms > 3.41), 'number_habitablerooms']=  np.nan

# %%
#492 outliers for Household

# %%
MergedDatasetsRenamed.head()
# Out:
#    hhid     s1q2_x  spend_tuitionfees  spend_textbooks  spend_exercisebooks  \
# 0    10  Village 1                0.0              0.0               2400.0
# 1    10  Village 1                0.0              0.0               2400.0
# 2    10  Village 1                0.0              0.0               2400.0
# 3    10  Village 1                0.0              0.0               2400.0
# 4    10  Village 1                0.0              0.0               2400.0
#
#    spend_schooluniform  spend_schoolboardingfees  spend_schooltransport  \
# 0                  0.0                    6000.0                 3000.0
# 1                  0.0                    6000.0                 3000.0
# 2                  0.0                    6000.0                 3000.0
# 3                  0.0                    6000.0                 3000.0
# 4                  0.0                    6000.0                 3000.0
#
# ...

# %%
MergedDatasetsRenamed['spend_exercisebooks'].describe()
# Out:
# count    17827.000000
# mean       420.067202
# std        634.122627
# min          0.000000
# 25%          0.000000
# 50%        160.000000
# 75%        600.000000
# max       3780.000000
# Name: spend_exercisebooks, dtype: float64

# %%
MergedDatasetsRenamed.to_csv('Outliers_Cleaning',index=False)
