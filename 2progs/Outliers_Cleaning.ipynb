# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
MergedDatasetsRenamed = pd.read_excel('../2progs/MergedDatasetsRenamed.xlsx',sheet_name='Sheet1',index_col = 0)

# %%
MergedDatasetsRenamed[['hh_purchasedfood7d', 'amountfood_purchased7d','foodwasfree','foodspent_localcurrecny', 
               'foodconsumed7d','quantityfood_consumedkg_pc']].describe().T[['mean', 'std', 'count', 'min','max']]
# Out:
#                                   mean         std    count       min      max
# amountfood_purchased7d       43.201819  404.407432  14557.0  0.000000  40000.0
# foodspent_localcurrecny     396.447658  553.982411  15074.0  0.000000   8500.0
# foodconsumed7d               32.160851  170.127047  15379.0  0.002000   5000.0
# quantityfood_consumedkg_pc    0.520312    0.795757  15498.0  0.000067     17.5

# %%
MergedDatasetsRenamed[MergedDatasetsRenamed['spend_schoolboardingfees'] > 50000]

#40 0bs over $50K....do we want to drop 40 obs
# Out:
#        hhid     s1q2_x  spend_tuitionfees  spend_textbooks  \
# 15754  5056  Village 2                0.0              0.0
# 15755  5056  Village 2                0.0              0.0
# 15756  5056  Village 2                0.0              0.0
# 15757  5056  Village 2                0.0              0.0
# 15758  5056  Village 2                0.0              0.0
# 15759  5056  Village 2                0.0              0.0
# 15760  5056  Village 2                0.0              0.0
# 15761  5056  Village 2                0.0              0.0
# 15762  5056  Village 2                0.0              0.0
# 15763  5056  Village 2                0.0              0.0
# 15764  5056  Village 2                0.0              0.0
# 15765  5056  Village 2                0.0              0.0
# 15766  5056  Village 2                0.0              0.0
# 15767  5056  Village 2                0.0              0.0
# 15768  5056  Village 2                0.0              0.0
# ...

# %%
#Method 1
MergedDatasetsRenamed[MergedDatasetsRenamed['amountfood_purchased7d'] > 10000]
MergedDatasetsRenamed.drop([14395])
# Out:
#        hhid     s1q2_x  spend_tuitionfees  spend_textbooks  \
# 0        10  Village 1                0.0              0.0
# 1        10  Village 1                0.0              0.0
# 2        10  Village 1                0.0              0.0
# 3        10  Village 1                0.0              0.0
# 4        10  Village 1                0.0              0.0
# ...     ...        ...                ...              ...
# 18075  6004  Village 3                0.0              0.0
# 18076  6004  Village 3                0.0              0.0
# 18077  6004  Village 3                0.0              0.0
# 18078  6004  Village 3                0.0              0.0
# 18079  6004  Village 3                0.0              0.0
#
#        spend_exercisebooks  spend_schooluniform  spend_schoolboardingfees  \
# 0              2400.000000                  0.0                    6000.0
# 1              2400.000000                  0.0                    6000.0
# ...

# %%
#Method 2
i = MergedDatasetsRenamed[((MergedDatasetsRenamed.amountfood_purchased7d > 10000))].index

# %%
MergedDatasetsRenamed.drop(i)
# Out:
#        hhid     s1q2_x  spend_tuitionfees  spend_textbooks  \
# 0        10  Village 1                0.0              0.0
# 1        10  Village 1                0.0              0.0
# 2        10  Village 1                0.0              0.0
# 3        10  Village 1                0.0              0.0
# 4        10  Village 1                0.0              0.0
# ...     ...        ...                ...              ...
# 18075  6004  Village 3                0.0              0.0
# 18076  6004  Village 3                0.0              0.0
# 18077  6004  Village 3                0.0              0.0
# 18078  6004  Village 3                0.0              0.0
# 18079  6004  Village 3                0.0              0.0
#
#        spend_exercisebooks  spend_schooluniform  spend_schoolboardingfees  \
# 0              2400.000000                  0.0                    6000.0
# 1              2400.000000                  0.0                    6000.0
# ...

# %%
# Out:
#        hhid     s1q2_x  spend_tuitionfees  spend_textbooks  \
# 14395  4655  Village 1                0.0              0.0
# 16590  5427  Village 3                0.0              0.0
#
#        spend_exercisebooks  spend_schooluniform  spend_schoolboardingfees  \
# 14395           480.000000                  0.0                       0.0
# 16590            40.000002                  4.0                       0.0
#
#        spend_schooltransport  spend_extratuition  spend_PTA  ...      hh_con  \
# 14395                    0.0                 0.0        0.0  ...  15480.1400
# 16590                    0.0                 0.0        0.0  ...   1972.0616
#
#        hh_con2011  hh_con2011_pd  pline_ipl   poorIPL       pgi       spg  \
# 14395  273.935270       9.006091        1.9  Non-poor  0.000000  0.000000
# 16590   34.897438       1.147313        1.9      Poor  0.418081  0.174791
#
#        weight_y.1  popweight   Dataset2
# 14395    5.557169  27.785843  Household
# ...

# %%
MergedDatasetsRenamed[MergedDatasetsRenamed['amountfood_purchased7d'] > 10000]
# Out:
#        hhid     s1q2_x  spend_tuitionfees  spend_textbooks  \
# 14395  4655  Village 1                0.0              0.0
# 16590  5427  Village 3                0.0              0.0
#
#        spend_exercisebooks  spend_schooluniform  spend_schoolboardingfees  \
# 14395           480.000000                  0.0                       0.0
# 16590            40.000002                  4.0                       0.0
#
#        spend_schooltransport  spend_extratuition  spend_PTA  ...      hh_con  \
# 14395                    0.0                 0.0        0.0  ...  15480.1400
# 16590                    0.0                 0.0        0.0  ...   1972.0616
#
#        hh_con2011  hh_con2011_pd  pline_ipl   poorIPL       pgi       spg  \
# 14395  273.935270       9.006091        1.9  Non-poor  0.000000  0.000000
# 16590   34.897438       1.147313        1.9      Poor  0.418081  0.174791
#
#        weight_y.1  popweight   Dataset2
# 14395    5.557169  27.785843  Household
# ...

# %%
#method 3

np.where(MergedDatasetsRenamed['spend_schoolboardingfees'] > 50000, 
                                                           50000,MergedDatasetsRenamed['spend_schoolboardingfees'])
# Out:
# array([6000., 6000., 6000., ...,    0.,    0.,    0.])

# %%
#method 4
MergedDatasetsRenamed[MergedDatasetsRenamed['amountfood_purchased7d'] == '40000']['spend_schooluniform']

# %%
MergedDatasetsRenamed[MergedDatasetsRenamed['amountfood_purchased7d'] == '40000']['spend_schooluniform']
